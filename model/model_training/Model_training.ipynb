# %%
from roboflow import Roboflow
rf = Roboflow(api_key="CcDqpFkghF2iME7I4UYr")
project = rf.workspace("projects-t3edn").project("head-detection_m")
version = project.version(5)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.15, to fix: `pip install ultralytics==8.0.196`
# Downloading Dataset Version Zip in head-detection_m-5 to yolov8:: 100%|█████████| 29203/29203 [00:07<00:00, 3717.81it/s]
# Extracting Dataset Version Zip to head-detection_m-5 in yolov8:: 100%|████████████| 1482/1482 [00:00<00:00, 8938.17it/s]

# %%
import cv2

image = cv2.imread("../../Data/videos_frames/855574-sd_640_360_25fps.mp4_frame_0.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# cv2.imshow("image", image)
# cv2.waitKey(0)

# cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt

plt.imshow(image)

# %%
image.shape
# Out:
# (360, 640, 3)

# %%
from utils import retrieve_image_paths, display_annotated_images, read_images_and_annotations
import os

_path = "head-detection_m-5"
directories = []
files = []

for item in os.listdir(_path):
    if os.path.isdir(os.path.join(_path, item)):
        directories.append(os.path.join(_path, item))
    elif os.path.isfile(os.path.join(_path, item)):
        files.append(os.path.join(_path, item))

directories, files
# Out:
# (['head-detection_m-5/train',
#   'head-detection_m-5/test',
#   'head-detection_m-5/valid'],
#  ['head-detection_m-5/README.dataset.txt',
#   'head-detection_m-5/data.yaml',
#   'head-detection_m-5/README.roboflow.txt'])

# %%
train_image_label_pairs = retrieve_image_paths(directories[0])
f"Train_sets : {len(train_image_label_pairs)}"
# Out:
# 'Train_sets : 642'

# %%
train_image_label_pairs[:5]
# Out:
# [('head-detection_m-5/train/images/7989754-hd_1920_1080_25fps-mp4_frame_25_jpg.rf.104ec1eabe031718896a4a83c43fea7c.jpg',
#   'head-detection_m-5/train/labels/7989754-hd_1920_1080_25fps-mp4_frame_25_jpg.rf.104ec1eabe031718896a4a83c43fea7c.txt'),
#  ('head-detection_m-5/train/images/vicky-hladynets-C8Ta0gwPbQg-unsplash_jpg.rf.361c591f431d2866daf17a80b22c8fe3.jpg',
#   'head-detection_m-5/train/labels/vicky-hladynets-C8Ta0gwPbQg-unsplash_jpg.rf.361c591f431d2866daf17a80b22c8fe3.txt'),
#  ('head-detection_m-5/train/images/WhatsApp-Video-2024-05-06-at-18-35-36-mp4_frame_2_jpg.rf.b4d92bb4d42b68a2b870320ed5ccd447.jpg',
#   'head-detection_m-5/train/labels/WhatsApp-Video-2024-05-06-at-18-35-36-mp4_frame_2_jpg.rf.b4d92bb4d42b68a2b870320ed5ccd447.txt'),
#  ('head-detection_m-5/train/images/4819600-hd_720_1366_25fps-mp4_frame_17_jpg.rf.66bff94d235b381c8d9cfc4799696320.jpg',
#   'head-detection_m-5/train/labels/4819600-hd_720_1366_25fps-mp4_frame_17_jpg.rf.66bff94d235b381c8d9cfc4799696320.txt'),
#  ('head-detection_m-5/train/images/petr-sevcovic-e12wQLAjQi0-unsplash_jpg.rf.1249134386d1e788567a39734bcf4363.jpg',
#   'head-detection_m-5/train/labels/petr-sevcovic-e12wQLAjQi0-unsplash_jpg.rf.1249134386d1e788567a39734bcf4363.txt')]

# %%
import random
images = []
annotations = []
selected_pairs = random.sample(train_image_label_pairs, min(5, len(train_image_label_pairs)))
for elt in selected_pairs:
    image, annotation = read_images_and_annotations(elt[0], elt[1])
    images.append(image)
    annotations.append(annotation)
annotations
# Out:
# [[{'class_id': 0,
#    'x_center': 0.346875,
#    'y_center': 0.365625,
#    'width': 0.1734375,
#    'height': 0.2484375},
#   {'class_id': 0,
#    'x_center': 0.575,
#    'y_center': 0.41875,
#    'width': 0.1515625,
#    'height': 0.2140625},
#   {'class_id': 0,
#    'x_center': 0.7515625,
#    'y_center': 0.371875,
#    'width': 0.2296875,
#    'height': 0.246875}],
#  [{'class_id': 0,
#    'x_center': 0.3109375,
#    'y_center': 0.7015625,
#    'width': 0.084375,
#    'height': 0.0671875}],
#  [{'class_id': 0,
#    'x_center': 0.584375,
#    'y_center': 0.440625,
#    'width': 0.2171875,
#    'height': 0.1515625},
#   {'class_id': 0,
#    'x_center': 0.628125,
#    'y_center': 0.6734375,
#    'width': 0.2453125,
#    'height': 0.171875},
#   {'class_id': 0,
#    'x_center': 0.628125,
#    'y_center': 0.26875,
#    'width': 0.246875,
#    'height': 0.2203125}],
#  [{'class_id': 0,
#    'x_center': 0.5515625,
#    'y_center': 0.59375,
#    'width': 0.046875,
#    'height': 0.034375}],
#  [{'class_id': 0,
#    'x_center': 0.5,
#    'y_center': 0.2671875,
#    'width': 0.3625,
#    'height': 0.425}]]

# %%
images
# Out:
# [array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]]], dtype=uint8),
#  array([[[  1,   1,   1],
#          [252, 252, 252],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[  1,   1,   1],
#          [252, 252, 252],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[  1,   1,   1],
#          [252, 252, 252],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[  1,   1,   1],
#          [252, 252, 252],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[  1,   1,   1],
#          [252, 252, 252],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[  1,   1,   1],
#          [252, 252, 252],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]]], dtype=uint8),
#  array([[[  1,   1,   1],
#          [252, 252, 252],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[  1,   1,   1],
#          [252, 252, 252],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[  1,   1,   1],
#          [252, 252, 252],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[  1,   1,   1],
#          [252, 252, 252],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[  1,   1,   1],
#          [252, 252, 252],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[  1,   1,   1],
#          [252, 252, 252],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]]], dtype=uint8),
#  array([[[  1,   1,   1],
#          [252, 252, 252],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[  1,   1,   1],
#          [252, 252, 252],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[  1,   1,   1],
#          [252, 252, 252],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[  1,   1,   1],
#          [252, 252, 252],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[  1,   1,   1],
#          [252, 252, 252],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[  1,   1,   1],
#          [252, 252, 252],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]]], dtype=uint8),
#  array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]]], dtype=uint8)]

# %%
image = cv2.imread('head-detection_m-5/train/images/7989754-hd_1920_1080_25fps-mp4_frame_25_jpg.rf.104ec1eabe031718896a4a83c43fea7c.jpg')
plt.imshow(image)

# %%
display_annotated_images(train_image_label_pairs)
# Out:
# [ WARN:0@15107.714] global loadsave.cpp:248 findDecoder imread_(''): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 display_annotated_images(train_image_label_pairs)
#
# File ~/Documents/Projects/ML Projects/FAceLinker/FaceDetect/model/model_training/utils/utils.py:110, in display_annotated_images(image_label_pairs, num_images, figsize, class_names)
#     107 fig, axes = plt.subplots(5, 5, figsize=figsize)
#     108 axes = axes.ravel()
# --> 110 # Get the list oof unique class identity
#     111 class_ids = set()
#     112 for _, label_path in selected_pairs:
#
# File ~/Documents/Projects/ML Projects/FAceLinker/FaceDetect/model/model_training/utils/utils.py:80, in read_images_and_annotations(image_file_path, label_file_path)
#      69 """
#      70 This function reads an image file and its corresponding label file, parses the annotations from the label file, and returns the image and the list of annotations.
#      71
#    (...)
#      77     tuple: A tuple containing the image (numpy array) and the list of annotations (list of dictionaries).
#      78 """
#      79 image = cv2.imread(image_file_path)
# ---> 80 if image is None:
#      81     raise FileNotFoundError(f"Image file {image_file_path} not found")
#      83 annotations = parse_annotations(label_file_path)
#
# FileNotFoundError: Image file None not found
